# %%
from google.colab import drive
drive.mount('/gdrive', force_remount = True)

# %%
import pandas as pd
df = pd.read_json('/gdrive/Shareddrives/인공지능과 기계학습_프로젝트/song_meta.json')
print(df)

df_data = df[['song_gn_dtl_gnr_basket', 'song_name', 'artist_name_basket', 'id']]

# %%
f=lambda x: x==['GN0101']
GN0101 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0101_id = df_data[GN0101].id

f=lambda x: x==['GN0101', 'GN0102']
GN0102 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0102_id = df_data[GN0102].id

f=lambda x: x==['GN0101', 'GN0103']
GN0103 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0103_id = df_data[GN0103].id

f=lambda x: x==['GN0104', 'GN0101']
GN0104 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0104_id = df_data[GN0104].id

f=lambda x: x==['GN0105', 'GN0101']
GN0105 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0105_id = df_data[GN0105].id

# %%
f=lambda x: x==['GN0201']
GN0201 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0201_id = df_data[GN0201].id

f=lambda x: x==['GN0202', 'GN0201']
GN0202 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0202_id = df_data[GN0202].id

f=lambda x: x==['GN0203', 'GN0201']
GN0203 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0203_id = df_data[GN0203].id

f=lambda x: x==['GN0204', 'GN0201']
GN0204 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0204_id = df_data[GN0204].id

f=lambda x: x==['GN0205', 'GN0201']
GN0205 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0205_id = df_data[GN0205].id

# %%
f=lambda x: x==['GN0601']
GN0601 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0601_id = df_data[GN0601].id

f=lambda x: x==['GN0602', 'GN0601']
GN0602_1 = df_data['song_gn_dtl_gnr_basket'].apply(f)
f=lambda x: x==['GN0603', 'GN0601']
GN0603_1 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0603 = pd.concat([GN0602_1, GN0603_1])

f=lambda x: x==['GN0601', 'GN0604']
GN0604 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0604_id = df_data[GN0604].id

f=lambda x: x==['GN0601', 'GN0605']
GN0605 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0605_id = df_data[GN0605].id

f=lambda x: x==['GN0601', 'GN0606']
GN0606 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0606_id = df_data[GN0606].id

# %%
f=lambda x: x==['GN0901']
GN0901 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0901_id = df_data[GN0901].id

f=lambda x: x==['GN0905','GN0901']
GN0905 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0905_id = df_data[GN0905].id

f=lambda x: x==['GN0906','GN0901']
GN0906 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0906_id = df_data[GN0906].id

f=lambda x: x==['GN0907','GN0901']
GN0907 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0907_id = df_data[GN0907].id

f=lambda x: x==['GN0908','GN0901']
GN0908 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN0908_id = df_data[GN0908].id

# %%
f=lambda x: x==['GN1201']
GN1201 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN1201_id = df_data[GN1201].id

f=lambda x: x==['GN1206','GN1201']
GN1206 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN1206_id = df_data[GN1206].id

f=lambda x: x==['GN1207','GN1201']
GN1207 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN1207_id = df_data[GN1207].id

f=lambda x: x==['GN1208','GN1201']
GN1208 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN1208_id = df_data[GN1208].id

f=lambda x: x==['GN1209','GN1201']
GN1209 = df_data['song_gn_dtl_gnr_basket'].apply(f)
GN1209_id = df_data[GN1209].id

# %%
import pandas as pd
train = pd.read_json('/gdrive/Shareddrives/인공지능과 기계학습_프로젝트/train.json')

tr_data = train[['tags', 'songs']]
tr_data

# %%
f=lambda x: x== ['기분전환']
song = tr_data['tags'].apply(f)
song1 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['신나는']
song = tr_data['tags'].apply(f)
song2 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['여름']
song = tr_data['tags'].apply(f)
song3 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['댄스']
song = tr_data['tags'].apply(f)
song4 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['드라이브']
song = tr_data['tags'].apply(f)
song5 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['시원']
song = tr_data['tags'].apply(f)
song6 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['휴가']
song = tr_data['tags'].apply(f)
song7 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['운동할때']
song = tr_data['tags'].apply(f)
song8 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['청량함']
song = tr_data['tags'].apply(f)
song9 = pd.DataFrame(tr_data[song])

tag1_1 = pd.concat([song1, song2, song3, song4, song5, song6, song7, song8, song9])
tag1 = tag1_1.drop(['tags'],axis = 1)

# %%
f=lambda x: x== ['힐링']
song = tr_data['tags'].apply(f)
song10 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['따듯한']
song = tr_data['tags'].apply(f)
song11 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['힘내']
song = tr_data['tags'].apply(f)
song12 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['쉼표']
song = tr_data['tags'].apply(f)
song13 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['잠들기전']
song = tr_data['tags'].apply(f)
song14 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['휴식']
song = tr_data['tags'].apply(f)
song15 = pd.DataFrame(tr_data[song])

tag2_1 = pd.concat([song10, song11, song12, song13, song14, song15])
tag2 = tag2_1.drop(['tags'],axis = 1)

# %%
f=lambda x: x== ['봄']
song = tr_data['tags'].apply(f)
song16 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['설렘']
song = tr_data['tags'].apply(f)
song17 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['사랑']
song = tr_data['tags'].apply(f)
song18 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['꿀']
song = tr_data['tags'].apply(f)
song19 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['달달']
song = tr_data['tags'].apply(f)
song20 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['연애중']
song = tr_data['tags'].apply(f)
song21 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['달달하게']
song = tr_data['tags'].apply(f)
song22 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['썸타는중']
song = tr_data['tags'].apply(f)
song23 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['러브송']
song = tr_data['tags'].apply(f)
song24 = pd.DataFrame(tr_data[song])

tag3_1 = pd.concat([song16, song17, song18, song19, song20, song21, song22, song23, song24])
tag3 = tag3_1.drop(['tags'],axis = 1)

# %%
f=lambda x: x== ['슬픔']
song = tr_data['tags'].apply(f)
song25 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['잔잔한']
song = tr_data['tags'].apply(f)
song26 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['이별']
song = tr_data['tags'].apply(f)
song27 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['혼자']
song = tr_data['tags'].apply(f)
song28 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['그리움']
song = tr_data['tags'].apply(f)
song29 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['외로움']
song = tr_data['tags'].apply(f)
song30 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['혼자있을때']
song = tr_data['tags'].apply(f)
song31 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['이별노래']
song = tr_data['tags'].apply(f)
song32 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['우울']
song = tr_data['tags'].apply(f)
song33 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['센치한']
song = tr_data['tags'].apply(f)
song34 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['끝']
song = tr_data['tags'].apply(f)
song35 = pd.DataFrame(tr_data[song])

f=lambda x: x== ['눈물']
song = tr_data['tags'].apply(f)
song36 = pd.DataFrame(tr_data[song])

tag4_1 = pd.concat([song25, song26, song27, song28, song29, song30, song31, song32, song33, song34, song35, song36])
tag4 = tag4_1.drop(['tags'],axis = 1)

tag0 = pd.concat([tag1, tag2, tag3, tag4])

# %%
GN0101_tag1 = []
for j in range(1, len(GN0101_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN0101_id.iloc[j] == tag1.iloc[k][0][i]):
        GN0101_tag1.append(GN0101_id.iloc[j])

GN0101_tag2 = []
for j in range(1, len(GN0101_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
       if (GN0101_id.iloc[j] == tag2.iloc[k][0][i]):
        GN0101_tag2.append(GN0101_id.iloc[j])

GN0101_tag3 = []
for j in range(1, len(GN0101_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
      if (GN0101_id.iloc[j] == tag3.iloc[k][0][i]):
        GN0101_tag3.append(GN0101_id.iloc[j])

GN0101_tag4 = []
for j in range(1, len(GN0101_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
      if (GN0101_id.iloc[j] == tag4.iloc[k][0][i]):
        GN0101_tag4.append(GN0101_id.iloc[j])

# %%
GN0102_tag1 = []
for j in range(1, len(GN0102_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN0102_id.iloc[j] == tag1.iloc[k][0][i]):
      #  print(GN0102_id.iloc[j])
        GN0102_tag1.append(GN0102_id.iloc[j])

GN0102_tag2 = []
for j in range(1, len(GN0102_id)):
    for k in range(1, len(tag2)):
      for i in range(1, len(tag2.iloc[k][0])):
        if (GN0102_id.iloc[j] == tag2.iloc[k][0][i]):
          GN0102_tag2.append(GN0102_id.iloc[j])

GN0102_tag3 = []
for j in range(1, len(GN0102_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
      if (GN0102_id.iloc[j] == tag3.iloc[k][0][i]):
        GN0102_tag3.append(GN0102_id.iloc[j])

GN0102_tag4 = []
for j in range(1, len(GN0102_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
      if (GN0102_id.iloc[j] == tag4.iloc[k][0][i]):
        GN0102_tag4.append(GN0102_id.iloc[j])

# %%
GN0103_tag1 = []
for j in range(1, len(GN0103_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN0103_id.iloc[j] == tag1.iloc[k][0][i]):
        GN0103_tag1.append(GN0103_id.iloc[j])

GN0103_tag2 = []
for j in range(1, len(GN0103_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
      if (GN0103_id.iloc[j] == tag2.iloc[k][0][i]):
        GN0103_tag2.append(GN0103_id.iloc[j])     

GN0103_tag3 = []
for j in range(1, len(GN0103_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
      if (GN0103_id.iloc[j] == tag3.iloc[k][0][i]):
        GN0103_tag3.append(GN0103_id.iloc[j])         

GN0103_tag4 = []
for j in range(1, len(GN0103_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
      if (GN0103_id.iloc[j] == tag4.iloc[k][0][i]):
        GN0103_tag4.append(GN0103_id.iloc[j])

# %%
GN0104_tag1 = []
for j in range(1, len(GN0104_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN0104_id.iloc[j] == tag1.iloc[k][0][i]):
        GN0104_tag1.append(GN0104_id.iloc[j])

GN0104_tag2 = []
for j in range(1, len(GN0104_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
      if (GN0104_id.iloc[j] == tag2.iloc[k][0][i]):
        GN0104_tag2.append(GN0104_id.iloc[j])

GN0104_tag3 = []
for j in range(1, len(GN0104_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
      if (GN0104_id.iloc[j] == tag3.iloc[k][0][i]):
        GN0104_tag3.append(GN0104_id.iloc[j])

GN0104_tag4 = []
for j in range(1, len(GN0104_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
      if (GN0104_id.iloc[j] == tag4.iloc[k][0][i]):
        GN0104_tag4.append(GN0104_id.iloc[j])

# %%
GN0105_tag1 = []
for j in range(1, len(GN0105_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN0105_id.iloc[j] == tag1.iloc[k][0][i]):
         GN0105_tag1.append(GN0105_id.iloc[j])

GN0105_tag2 = []
for j in range(1, len(GN0105_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
       if (GN0105_id.iloc[j] == tag2.iloc[k][0][i]):
         GN0105_tag2.append(GN0105_id.iloc[j])         

GN0105_tag3 = []
for j in range(1, len(GN0105_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
       if (GN0105_id.iloc[j] == tag3.iloc[k][0][i]):
         GN0105_tag3.append(GN0105_id.iloc[j])      

GN0105_tag4 = []
for j in range(1, len(GN0105_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
       if (GN0105_id.iloc[j] == tag4.iloc[k][0][i]):
         GN0105_tag4.append(GN0105_id.iloc[j])

# %%
GN0201_tag1 = []
for j in range(1, len(GN0201_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN0201_id.iloc[j] == tag1.iloc[k][0][i]):
        GN0201_tag1.append(GN0201_id.iloc[j])

GN0201_tag2 = []
for j in range(1, len(GN0201_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
      if (GN0201_id.iloc[j] == tag2.iloc[k][0][i]):
        GN0201_tag2.append(GN0201_id.iloc[j])   

GN0201_tag3 = []
for j in range(1, len(GN0201_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
      if (GN0201_id.iloc[j] == tag3.iloc[k][0][i]):
        GN0201_tag3.append(GN0201_id.iloc[j])        

GN0201_tag4 = []
for j in range(1, len(GN0201_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
      if (GN0201_id.iloc[j] == tag4.iloc[k][0][i]):
        GN0201_tag4.append(GN0201_id.iloc[j])

# %%
GN0202_tag1 = []
for j in range(1, len(GN0202_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
       if (GN0202_id.iloc[j] == tag1.iloc[k][0][i]):
         GN0202_tag1.append(GN0202_id.iloc[j])

GN0202_tag2 = []
for j in range(1, len(GN0202_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
       if (GN0202_id.iloc[j] == tag2.iloc[k][0][i]):
         GN0202_tag2.append(GN0202_id.iloc[j])     

GN0202_tag3 = []
for j in range(1, len(GN0202_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
       if (GN0202_id.iloc[j] == tag3.iloc[k][0][i]):
         GN0202_tag3.append(GN0202_id.iloc[j])

GN0202_tag4 = []
for j in range(1, len(GN0202_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
       if (GN0202_id.iloc[j] == tag4.iloc[k][0][i]):
         GN0202_tag4.append(GN0202_id.iloc[j])

# %%
GN0203_tag1 = []
for j in range(1, len(GN0203_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN0203_id.iloc[j] == tag1.iloc[k][0][i]):
        GN0203_tag1.append(GN0203_id.iloc[j])

GN0203_tag2 = []
for j in range(1, len(GN0203_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
      if (GN0203_id.iloc[j] == tag2.iloc[k][0][i]):
        GN0203_tag2.append(GN0203_id.iloc[j])    

GN0203_tag3 = []
for j in range(1, len(GN0203_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
      if (GN0203_id.iloc[j] == tag3.iloc[k][0][i]):
        GN0203_tag3.append(GN0203_id.iloc[j])   

GN0203_tag4 = []
for j in range(1, len(GN0203_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
      if (GN0203_id.iloc[j] == tag4.iloc[k][0][i]):
        GN0203_tag4.append(GN0203_id.iloc[j])

# %%
GN0204_tag1 = []
for j in range(1, len(GN0204_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
       if (GN0204_id.iloc[j] == tag1.iloc[k][0][i]):
         GN0204_tag1.append(GN0204_id.iloc[j])

GN0204_tag2 = []
for j in range(1, len(GN0204_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
       if (GN0204_id.iloc[j] == tag2.iloc[k][0][i]):
         GN0204_tag2.append(GN0204_id.iloc[j])

GN0204_tag3 = []
for j in range(1, len(GN0204_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
       if (GN0204_id.iloc[j] == tag3.iloc[k][0][i]):
         GN0204_tag3.append(GN0204_id.iloc[j])   

GN0204_tag4 = []
for j in range(1, len(GN0204_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
       if (GN0204_id.iloc[j] == tag4.iloc[k][0][i]):
         GN0204_tag4.append(GN0204_id.iloc[j])

# %%
GN0205_tag1 = []
for j in range(1, len(GN0205_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN0205_id.iloc[j] == tag1.iloc[k][0][i]):
        GN0205_tag1.append(GN0205_id.iloc[j])

GN0205_tag2 = []
for j in range(1, len(GN0205_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
      if (GN0205_id.iloc[j] == tag2.iloc[k][0][i]):
        GN0205_tag2.append(GN0205_id.iloc[j])     

GN0205_tag3 = []
for j in range(1, len(GN0205_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
      if (GN0205_id.iloc[j] == tag3.iloc[k][0][i]):
        GN0205_tag3.append(GN0205_id.iloc[j])

GN0205_tag4 = []
for j in range(1, len(GN0205_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
      if (GN0205_id.iloc[j] == tag4.iloc[k][0][i]):
        GN0205_tag4.append(GN0205_id.iloc[j])

# %%
GN0601_tag1 = []
for j in range(1, len(GN0601_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN0601_id.iloc[j] == tag1.iloc[k][0][i]):
        GN0601_tag1.append(GN0601_id.iloc[j])

GN0601_tag2 = []
for j in range(1, len(GN0601_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
      if (GN0601_id.iloc[j] == tag1.iloc[k][0][i]):
        GN0601_tag2.append(GN0601_id.iloc[j])     

GN0601_tag3 = []
for j in range(1, len(GN0601_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
      if (GN0601_id.iloc[j] == tag3.iloc[k][0][i]):
        GN0601_tag3.append(GN0601_id.iloc[j])    

GN0601_tag4 = []
for j in range(1, len(GN0601_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
      if (GN0601_id.iloc[j] == tag4.iloc[k][0][i]):
        GN0601_tag4.append(GN0601_id.iloc[j])

# %%
GN0603_tag1 = []
for j in range(1, len(GN0603_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN0603_id.iloc[j] == tag1.iloc[k][0][i]):
        GN0603_tag1.append(GN0603_id.iloc[j])

GN0603_tag2 = []
for j in range(1, len(GN0603_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
      if (GN0603_id.iloc[j] == tag2.iloc[k][0][i]):
        GN0603_tag2.append(GN0603_id.iloc[j])

GN0603_tag3 = []
for j in range(1, len(GN0603_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
      if (GN0603_id.iloc[j] == tag3.iloc[k][0][i]):
        GN0603_tag3.append(GN0603_id.iloc[j])         

GN0603_tag4 = []
for j in range(1, len(GN0603_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
      if (GN0603_id.iloc[j] == tag4.iloc[k][0][i]):
        GN0603_tag4.append(GN0603_id.iloc[j])

# %%
GN0604_tag1 = []
for j in range(1, len(GN0604_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN0604_id.iloc[j] == tag1.iloc[k][0][i]):
        GN0604_tag1.append(GN0604_id.iloc[j])

GN0604_tag2 = []
for j in range(1, len(GN0604_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
      if (GN0604_id.iloc[j] == tag2.iloc[k][0][i]):
        GN0604_tag2.append(GN0604_id.iloc[j])  

GN0604_tag3 = []
for j in range(1, len(GN0604_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
      if (GN0604_id.iloc[j] == tag3.iloc[k][0][i]):
        GN0604_tag3.append(GN0604_id.iloc[j])  

GN0604_tag4 = []
for j in range(1, len(GN0604_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
      if (GN0604_id.iloc[j] == tag4.iloc[k][0][i]):
        GN0604_tag4.append(GN0604_id.iloc[j])

# %%
GN0605_tag1 = []
for j in range(1, len(GN0605_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN0605_id.iloc[j] == tag1.iloc[k][0][i]):
        GN0605_tag1.append(GN0605_id.iloc[j])

GN0605_tag2 = []
for j in range(1, len(GN0605_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
      if (GN0605_id.iloc[j] == tag2.iloc[k][0][i]):
        GN0605_tag2.append(GN0605_id.iloc[j])        

GN0605_tag3 = []
for j in range(1, len(GN0605_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
      if (GN0605_id.iloc[j] == tag3.iloc[k][0][i]):
        GN0605_tag3.append(GN0605_id.iloc[j])      

GN0605_tag4 = []
for j in range(1, len(GN0605_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
      if (GN0605_id.iloc[j] == tag4.iloc[k][0][i]):
        GN0605_tag4.append(GN0605_id.iloc[j])

# %%
GN0606_tag1 = []
for j in range(1, len(GN0606_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN0606_id.iloc[j] == tag1.iloc[k][0][i]):
        GN0606_tag1.append(GN0606_id.iloc[j])

GN0606_tag2 = []
for j in range(1, len(GN0606_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
      if (GN0606_id.iloc[j] == tag2.iloc[k][0][i]):
        GN0606_tag2.append(GN0606_id.iloc[j])     

GN0606_tag3 = []
for j in range(1, len(GN0606_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
      if (GN0606_id.iloc[j] == tag3.iloc[k][0][i]):
        GN0606_tag3.append(GN0606_id.iloc[j])

GN0606_tag4 = []
for j in range(1, len(GN0606_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
      if (GN0606_id.iloc[j] == tag4.iloc[k][0][i]):
        GN0606_tag4.append(GN0606_id.iloc[j])

# %%
GN0901_tag1 = []
for j in range(1, len(GN0901_id)):
   for k in range(1, len(tag1)):
     for i in range(1, len(tag1.iloc[k][0])):
       if (GN0901_id.iloc[j] == tag1.iloc[k][0][i]):
         GN0901_tag1.append(GN0901_id.iloc[j])

GN0901_tag2 = []
for j in range(1, len(GN0901_id)):
   for k in range(1, len(tag2)):
     for i in range(1, len(tag2.iloc[k][0])):
       if (GN0901_id.iloc[j] == tag2.iloc[k][0][i]):
         GN0901_tag2.append(GN0901_id.iloc[j])

GN0901_tag3 = []
for j in range(1, len(GN0901_id)):
   for k in range(1, len(tag3)):
     for i in range(1, len(tag3.iloc[k][0])):
       if (GN0901_id.iloc[j] == tag3.iloc[k][0][i]):
         GN0901_tag3.append(GN0901_id.iloc[j])

GN0901_tag4 = []
for j in range(1, len(GN0901_id)):
   for k in range(1, len(tag4)):
     for i in range(1, len(tag4.iloc[k][0])):
       if (GN0901_id.iloc[j] == tag4.iloc[k][0][i]):
         GN0901_tag4.append(GN0901_id.iloc[j])

# %%
GN0905_tag1 = []
for j in range(1, len(GN0905_id)):
   for k in range(1, len(tag1)):
     for i in range(1, len(tag1.iloc[k][0])):
       if (GN0905_id.iloc[j] == tag1.iloc[k][0][i]):
         GN0905_tag1.append(GN0905_id.iloc[j])

GN0905_tag2 = []
for j in range(1, len(GN0905_id)):
   for k in range(1, len(tag2)):
     for i in range(1, len(tag2.iloc[k][0])):
       if (GN0905_id.iloc[j] == tag2.iloc[k][0][i]):
         GN0905_tag2.append(GN0905_id.iloc[j])

GN0905_tag3 = []
for j in range(1, len(GN0905_id)):
   for k in range(1, len(tag3)):
     for i in range(1, len(tag3.iloc[k][0])):
       if (GN0905_id.iloc[j] == tag3.iloc[k][0][i]):
         GN0905_tag3.append(GN0905_id.iloc[j])

GN0905_tag4 = []
for j in range(1, len(GN0905_id)):
   for k in range(1, len(tag4)):
     for i in range(1, len(tag4.iloc[k][0])):
       if (GN0905_id.iloc[j] == tag4.iloc[k][0][i]):
         GN0905_tag4.append(GN0905_id.iloc[j])

# %%
GN0906_tag1 = []
for j in range(1, len(GN0906_id)):
   for k in range(1, len(tag1)):
     for i in range(1, len(tag1.iloc[k][0])):
       if (GN0906_id.iloc[j] == tag1.iloc[k][0][i]):
         GN0906_tag1.append(GN0906_id.iloc[j])

GN0906_tag2 = []
for j in range(1, len(GN0906_id)):
   for k in range(1, len(tag2)):
     for i in range(1, len(tag2.iloc[k][0])):
       if (GN0906_id.iloc[j] == tag2.iloc[k][0][i]):
         GN0906_tag2.append(GN0906_id.iloc[j])

GN0906_tag3 = []
for j in range(1, len(GN0906_id)):
   for k in range(1, len(tag3)):
     for i in range(1, len(tag3.iloc[k][0])):
       if (GN0906_id.iloc[j] == tag3.iloc[k][0][i]):
         GN0906_tag3.append(GN0906_id.iloc[j])

GN0906_tag4 = []
for j in range(1, len(GN0906_id)):
   for k in range(1, len(tag4)):
     for i in range(1, len(tag4.iloc[k][0])):
       if (GN0906_id.iloc[j] ==tag4.iloc[k][0][i]):
         GN0906_tag4.append(GN0906_id.iloc[j])

# %%
GN0907_tag1 = []
for j in range(1, len(GN0907_id)):
   for k in range(1, len(tag1)):
     for i in range(1, len(tag1.iloc[k][0])):
       if (GN0907_id.iloc[j] == tag1.iloc[k][0][i]):
         GN0907_tag1.append(GN0907_id.iloc[j])

GN0907_tag2 = []
for j in range(1, len(GN0907_id)):
   for k in range(1, len(tag2)):
     for i in range(1, len(tag2.iloc[k][0])):
       if (GN0907_id.iloc[j] == tag2.iloc[k][0][i]):
         GN0907_tag2.append(GN0907_id.iloc[j])

GN0907_tag3 = []
for j in range(1, len(GN0907_id)):
   for k in range(1, len(tag3)):
     for i in range(1, len(tag3.iloc[k][0])):
       if (GN0907_id.iloc[j] == tag3.iloc[k][0][i]):
         GN0907_tag3.append(GN0907_id.iloc[j])

GN0907_tag4 = []
for j in range(1, len(GN0907_id)):
   for k in range(1, len(tag4)):
     for i in range(1, len(tag4.iloc[k][0])):
       if (GN0907_id.iloc[j] == tag4.iloc[k][0][i]):
         GN0907_tag4.append(GN0907_id.iloc[j])

# %%
GN0908_tag1 = []
for j in range(1, len(GN0908_id)):
   for k in range(1, len(tag1)):
     for i in range(1, len(tag1.iloc[k][0])):
       if (GN0908_id.iloc[j] == tag1.iloc[k][0][i]):
         GN0908_tag1.append(GN0908_id.iloc[j])

GN0908_tag2 = []
for j in range(1, len(GN0908_id)):
   for k in range(1, len(tag2)):
     for i in range(1, len(tag2.iloc[k][0])):
       if (GN0908_id.iloc[j] == tag2.iloc[k][0][i]):
         GN0908_tag2.append(GN0908_id.iloc[j])

GN0908_tag3 = []
for j in range(1, len(GN0908_id)):
   for k in range(1, len(tag3)):
     for i in range(1, len(tag3.iloc[k][0])):
       if (GN0908_id.iloc[j] == tag3.iloc[k][0][i]):
         GN0908_tag3.append(GN0908_id.iloc[j])

GN0908_tag4 = []
for j in range(1, len(GN0908_id)):
   for k in range(1, len(tag4)):
     for i in range(1, len(tag4.iloc[k][0])):
       if (GN0908_id.iloc[j] == tag4.iloc[k][0][i]):
         GN0908_tag4.append(GN0908_id.iloc[j])

# %%
GN1201_tag1 = []
for j in range(1, len(GN1201_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN1201_id.iloc[j] == tag1.iloc[k][0][i]):
        GN1201_tag1.append(GN1201_id.iloc[j])

GN1201_tag2 = []
for j in range(1, len(GN1201_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
      if (GN1201_id.iloc[j] == tag2.iloc[k][0][i]):
        GN1201_tag2.append(GN1201_id.iloc[j])

GN1201_tag3 = []
for j in range(1, len(GN1201_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
      if (GN1201_id.iloc[j] == tag3.iloc[k][0][i]):
        GN1201_tag3.append(GN1201_id.iloc[j])

GN1201_tag4 = []
for j in range(1, len(GN1201_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
      if (GN1201_id.iloc[j] == tag4.iloc[k][0][i]):
        GN1201_tag4.append(GN1201_id.iloc[j])

# %%
GN1206_tag1 = []
for j in range(1, len(GN1206_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN1206_id.iloc[j] == tag1.iloc[k][0][i]):
        GN1206_tag1.append(GN1206_id.iloc[j])

GN1206_tag2 = []
for j in range(1, len(GN1206_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
      if (GN1206_id.iloc[j] == tag2.iloc[k][0][i]):
        GN1206_tag2.append(GN1206_id.iloc[j])

GN1206_tag3 = []
for j in range(1, len(GN1206_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
      if (GN1206_id.iloc[j] == tag3.iloc[k][0][i]):
        GN1206_tag3.append(GN1206_id.iloc[j])

GN1206_tag4 = []
for j in range(1, len(GN1206_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
      if (GN1206_id.iloc[j] == tag4.iloc[k][0][i]):
        GN1206_tag4.append(GN1206_id.iloc[j])

# %%
GN1207_tag1 = []
for j in range(1, len(GN1207_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN1207_id.iloc[j] == tag1.iloc[k][0][i]):
        GN1207_tag1.append(GN1207_id.iloc[j])

GN1207_tag2 = []
for j in range(1, len(GN1207_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
      if (GN1207_id.iloc[j] == tag2.iloc[k][0][i]):
        GN1207_tag2.append(GN1207_id.iloc[j])

GN1207_tag3 = []
for j in range(1, len(GN1207_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
      if (GN1207_id.iloc[j] == tag3.iloc[k][0][i]):
        GN1207_tag3.append(GN1207_id.iloc[j])

GN1207_tag4 = []
for j in range(1, len(GN1207_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
      if (GN1207_id.iloc[j] == tag4.iloc[k][0][i]):
        GN1207_tag4.append(GN1207_id.iloc[j])

# %%
GN1208_tag1 = []
for j in range(1, len(GN1208_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN1208_id.iloc[j] == tag1.iloc[k][0][i]):
        GN1208_tag1.append(GN1208_id.iloc[j])

GN1208_tag2 = []
for j in range(1, len(GN1208_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
      if (GN1208_id.iloc[j] == tag2.iloc[k][0][i]):
        GN1208_tag2.append(GN1208_id.iloc[j])

GN1208_tag3 = []
for j in range(1, len(GN1208_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
      if (GN1208_id.iloc[j] == tag3.iloc[k][0][i]):
        GN1208_tag3.append(GN1208_id.iloc[j])

GN1208_tag4 = []
for j in range(1, len(GN1208_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
      if (GN1208_id.iloc[j] == tag4.iloc[k][0][i]):
        GN1208_tag4.append(GN1208_id.iloc[j])

# %%
GN1209_tag1 = []
for j in range(1, len(GN1209_id)):
  for k in range(1, len(tag1)):
    for i in range(1, len(tag1.iloc[k][0])):
      if (GN1209_id.iloc[j] == tag1.iloc[k][0][i]):
        GN1209_tag1.append(GN1209_id.iloc[j])

GN1209_tag2 = []
for j in range(1, len(GN1209_id)):
  for k in range(1, len(tag2)):
    for i in range(1, len(tag2.iloc[k][0])):
      if (GN1209_id.iloc[j] == tag2.iloc[k][0][i]):
        GN1209_tag2.append(GN1209_id.iloc[j])

GN1209_tag3 = []
for j in range(1, len(GN1209_id)):
  for k in range(1, len(tag3)):
    for i in range(1, len(tag3.iloc[k][0])):
      if (GN1209_id.iloc[j] == tag3.iloc[k][0][i]):
        GN1209_tag3.append(GN1209_id.iloc[j])

GN1209_tag4 = []
for j in range(1, len(GN1209_id)):
  for k in range(1, len(tag4)):
    for i in range(1, len(tag4.iloc[k][0])):
      if (GN1209_id.iloc[j] == tag4.iloc[k][0][i]):
        GN1209_tag4.append(GN1209_id.iloc[j])

# %%
import pickle

filePath = '/gdrive/Shareddrives/인공지능과 기계학습_프로젝트/gn0101_tag1.txt'
with open(filePath, 'wb') as lf:
    pickle.dump(GN0101_tag1, lf)

with open(filePath, 'rb') as lf:
    readList = pickle.load(lf)
    print(readList)

# %% [markdown]
# GN0101_tag1 ~ GN1209_tag4까지 모두 수행

# %%
## GN01~

import pickle
path = '/gdrive/Shareddrives/인공지능과 기계학습_프로젝트/data/'
with open(path + 'gn0101_tag1.txt', 'rb') as f:
    GN0101_tag1 = pickle.load(f)
with open(path + 'gn0101_tag2.txt', 'rb') as f:
    GN0101_tag2 = pickle.load(f)
with open(path + 'gn0101_tag3.txt', 'rb') as f:
    GN0101_tag3 = pickle.load(f)
with open(path + 'gn0101_tag4.txt', 'rb') as f:
    GN0101_tag4 = pickle.load(f)    

with open(path + 'gn0102_tag1.txt', 'rb') as f:
    GN0102_tag1 = pickle.load(f)
with open(path + 'gn0102_tag2.txt', 'rb') as f:
    GN0102_tag2 = pickle.load(f)
with open(path + 'gn0102_tag3.txt', 'rb') as f:
    GN0102_tag3 = pickle.load(f)
with open(path + 'gn0102_tag4.txt', 'rb') as f:
    GN0102_tag4 = pickle.load(f)    

with open(path + 'gn0103_tag1.txt', 'rb') as f:
    GN0102_tag1 = pickle.load(f)
with open(path + 'gn0103_tag2.txt', 'rb') as f:
    GN0102_tag2 = pickle.load(f)
with open(path + 'gn0103_tag2.txt', 'rb') as f:
    GN0103_tag2 = pickle.load(f)
with open(path + 'gn0103_tag3.txt', 'rb') as f:
    GN0103_tag3 = pickle.load(f)

with open(path + 'gn0104_tag1.txt', 'rb') as f:
    GN0105_tag1 = pickle.load(f)
with open(path + 'gn0104_tag2.txt', 'rb') as f:
    GN0105_tag2 = pickle.load(f)
with open(path + 'gn0104_tag3.txt', 'rb') as f:
    GN0105_tag3 = pickle.load(f)
with open(path + 'gn0104_tag4.txt', 'rb') as f:
    GN0105_tag4 = pickle.load(f) 

with open(path + 'gn0105_tag1.txt', 'rb') as f:
    GN0105_tag1 = pickle.load(f)
with open(path + 'gn0105_tag2.txt', 'rb') as f:
    GN0105_tag2 = pickle.load(f)
with open(path + 'gn0105_tag3.txt', 'rb') as f:
    GN0105_tag3 = pickle.load(f)
with open(path + 'gn0105_tag4.txt', 'rb') as f:
    GN0105_tag4 = pickle.load(f)

# %%
## GN02~

path = '/gdrive/Shareddrives/인공지능과 기계학습_프로젝트/data/'
with open(path + 'gn0201_tag1.txt', 'rb') as f:
    GN0201_tag1 = pickle.load(f)
with open(path + 'gn0201_tag2.txt', 'rb') as f:
    GN0201_tag2 = pickle.load(f)
with open(path + 'gn0201_tag3.txt', 'rb') as f:
    GN0201_tag3 = pickle.load(f)
with open(path + 'gn0201_tag4.txt', 'rb') as f:
    GN0201_tag4 = pickle.load(f) 

with open(path + 'gn0202_tag1.txt', 'rb') as f:
    GN0202_tag1 = pickle.load(f)
with open(path + 'gn0202_tag2.txt', 'rb') as f:
    GN0202_tag2 = pickle.load(f)
with open(path + 'gn0202_tag3.txt', 'rb') as f:
    GN0202_tag3 = pickle.load(f)
with open(path + 'gn0202_tag4.txt', 'rb') as f:
    GN0202_tag4 = pickle.load(f) 

with open(path + 'gn0203_tag1.txt', 'rb') as f:
    GN0203_tag1 = pickle.load(f)
with open(path + 'gn0203_tag2.txt', 'rb') as f:
    GN0203_tag2 = pickle.load(f)
with open(path + 'gn0203_tag3.txt', 'rb') as f:
    GN0203_tag3 = pickle.load(f)
with open(path + 'gn0203_tag4.txt', 'rb') as f:
    GN0203_tag4 = pickle.load(f) 

with open(path + 'gn0204_tag1.txt', 'rb') as f:
    GN0203_tag1 = pickle.load(f)
with open(path + 'gn0204_tag2.txt', 'rb') as f:
    GN0203_tag2 = pickle.load(f)
with open(path + 'gn0204_tag3.txt', 'rb') as f:
    GN0203_tag3 = pickle.load(f)
with open(path + 'gn0204_tag4.txt', 'rb') as f:
    GN0203_tag4 = pickle.load(f) 

with open(path + 'gn0205_tag1.txt', 'rb') as f:
    GN0203_tag1 = pickle.load(f)
with open(path + 'gn0205_tag2.txt', 'rb') as f:
    GN0203_tag2 = pickle.load(f)
with open(path + 'gn0205_tag3.txt', 'rb') as f:
    GN0203_tag3 = pickle.load(f)
with open(path + 'gn0205_tag4.txt', 'rb') as f:
    GN0203_tag4 = pickle.load(f)

# %%
## GN06~

path = '/gdrive/Shareddrives/인공지능과 기계학습_프로젝트/data/'
with open(path + 'gn0601_tag1.txt', 'rb') as f:
    GN0601_tag1 = pickle.load(f)
with open(path + 'gn0601_tag2.txt', 'rb') as f:
    GN0601_tag2 = pickle.load(f)
with open(path + 'gn0601_tag3.txt', 'rb') as f:
    GN0601_tag3 = pickle.load(f)
with open(path + 'gn0601_tag4.txt', 'rb') as f:
    GN0601_tag4 = pickle.load(f)

with open(path + 'gn0603_tag1.txt', 'rb') as f:
    GN0603_tag1 = pickle.load(f)
with open(path + 'gn0603_tag2.txt', 'rb') as f:
    GN0603_tag2 = pickle.load(f)
with open(path + 'gn0603_tag3.txt', 'rb') as f:
    GN0603_tag3 = pickle.load(f)
with open(path + 'gn0603_tag4.txt', 'rb') as f:
    GN0603_tag4 = pickle.load(f) 

with open(path + 'gn0604_tag1.txt', 'rb') as f:
    GN0604_tag1 = pickle.load(f)
with open(path + 'gn0604_tag2.txt', 'rb') as f:
    GN0604_tag2 = pickle.load(f)
with open(path + 'gn0604_tag3.txt', 'rb') as f:
    GN0604_tag3 = pickle.load(f)
with open(path + 'gn0604_tag4.txt', 'rb') as f:
    GN0604_tag4 = pickle.load(f) 

with open(path + 'gn0605_tag1.txt', 'rb') as f:
    GN0605_tag1 = pickle.load(f)
with open(path + 'gn0605_tag2.txt', 'rb') as f:
    GN0605_tag2 = pickle.load(f)
with open(path + 'gn0605_tag3.txt', 'rb') as f:
    GN0605_tag3 = pickle.load(f)
with open(path + 'gn0605_tag4.txt', 'rb') as f:
    GN0605_tag4 = pickle.load(f) 

with open(path + 'gn0606_tag1.txt', 'rb') as f:
    GN0606_tag1 = pickle.load(f)
with open(path + 'gn0606_tag2.txt', 'rb') as f:
    GN0606_tag2 = pickle.load(f)
with open(path + 'gn0606_tag3.txt', 'rb') as f:
    GN0606_tag3 = pickle.load(f)
with open(path + 'gn0606_tag4.txt', 'rb') as f:
    GN0606_tag4 = pickle.load(f)

# %%
## GN09~

path = '/gdrive/Shareddrives/인공지능과 기계학습_프로젝트/data/'
with open(path + 'gn0901_tag1.txt', 'rb') as f:
    GN0901_tag1 = pickle.load(f)
with open(path + 'gn0901_tag2.txt', 'rb') as f:
    GN0901_tag2 = pickle.load(f)
with open(path + 'gn0901_tag3.txt', 'rb') as f:
    GN0901_tag3 = pickle.load(f)
with open(path + 'gn0901_tag4.txt', 'rb') as f:
    GN0901_tag4 = pickle.load(f)

with open(path + 'gn0905_tag1.txt', 'rb') as f:
    GN0905_tag1 = pickle.load(f)
with open(path + 'gn0905_tag2.txt', 'rb') as f:
    GN0905_tag2 = pickle.load(f)
with open(path + 'gn0905_tag3.txt', 'rb') as f:
    GN0905_tag3 = pickle.load(f)
with open(path + 'gn0905_tag4.txt', 'rb') as f:
    GN0905_tag4 = pickle.load(f)

with open(path + 'gn0906_tag1.txt', 'rb') as f:
    GN0906_tag1 = pickle.load(f)
with open(path + 'gn0906_tag2.txt', 'rb') as f:
    GN0906_tag2 = pickle.load(f)
with open(path + 'gn0906_tag3.txt', 'rb') as f:
    GN0906_tag3 = pickle.load(f)
with open(path + 'gn0906_tag4.txt', 'rb') as f:
    GN0906_tag4 = pickle.load(f)

with open(path + 'gn0907_tag1.txt', 'rb') as f:
    GN0907_tag1 = pickle.load(f)
with open(path + 'gn0907_tag2.txt', 'rb') as f:
    GN0907_tag2 = pickle.load(f)
with open(path + 'gn0907_tag3.txt', 'rb') as f:
    GN0907_tag3 = pickle.load(f)
with open(path + 'gn0907_tag4.txt', 'rb') as f:
    GN0907_tag4 = pickle.load(f)

with open(path + 'gn0908_tag1.txt', 'rb') as f:
    GN0908_tag1 = pickle.load(f)
with open(path + 'gn0908_tag2.txt', 'rb') as f:
    GN0908_tag2 = pickle.load(f)
with open(path + 'gn0908_tag3.txt', 'rb') as f:
    GN0908_tag3 = pickle.load(f)
with open(path + 'gn0908_tag4.txt', 'rb') as f:
    GN0908_tag4 = pickle.load(f)

# %%
## GN12~

path = '/gdrive/Shareddrives/인공지능과 기계학습_프로젝트/data/'
with open(path + 'gn1201_tag1.txt', 'rb') as f:
    GN1201_tag1 = pickle.load(f)
with open(path + 'gn1201_tag1.txt', 'rb') as f:
    GN1201_tag1 = pickle.load(f)
with open(path + 'gn1201_tag3.txt', 'rb') as f:
    GN1201_tag3 = pickle.load(f)
with open(path + 'gn1201_tag4.txt', 'rb') as f:
    GN1201_tag4 = pickle.load(f)

with open(path + 'gn1206_tag1.txt', 'rb') as f:
    GN1206_tag1 = pickle.load(f)
with open(path + 'gn1206_tag1.txt', 'rb') as f:
    GN1206_tag1 = pickle.load(f)
with open(path + 'gn1206_tag3.txt', 'rb') as f:
    GN1206_tag3 = pickle.load(f)
with open(path + 'gn1206_tag4.txt', 'rb') as f:
    GN1206_tag4 = pickle.load(f)

with open(path + 'gn1207_tag1.txt', 'rb') as f:
    GN1207_tag1 = pickle.load(f)
with open(path + 'gn1207_tag1.txt', 'rb') as f:
    GN1207_tag1 = pickle.load(f)
with open(path + 'gn1207_tag3.txt', 'rb') as f:
    GN1207_tag3 = pickle.load(f)
with open(path + 'gn1207_tag4.txt', 'rb') as f:
    GN1207_tag4 = pickle.load(f)

with open(path + 'gn1208_tag1.txt', 'rb') as f:
    GN1208_tag1 = pickle.load(f)
with open(path + 'gn1208_tag1.txt', 'rb') as f:
    GN1208_tag1 = pickle.load(f)
with open(path + 'gn1208_tag3.txt', 'rb') as f:
    GN1208_tag3 = pickle.load(f)
with open(path + 'gn1208_tag4.txt', 'rb') as f:
    GN1208_tag4 = pickle.load(f)

with open(path + 'gn1209_tag1.txt', 'rb') as f:
    GN1209_tag1 = pickle.load(f)
with open(path + 'gn1209_tag1.txt', 'rb') as f:
    GN1209_tag1 = pickle.load(f)
with open(path + 'gn1209_tag3.txt', 'rb') as f:
    GN1209_tag3 = pickle.load(f)
with open(path + 'gn1209_tag4.txt', 'rb') as f:
    GN1209_tag4 = pickle.load(f)

# %% [markdown]
# ## Music Recommendation System

# %%
#@title 음악추천시스템
Genre = "Rock/metal" #@param ["ALL","Balad","Dance","Rock/metal","POP","Rap/Hipop"]
Year = 'ALL' #@param ["ALL","(POP)1960-1970","(POP)1980-1990","~1980","1990","2000","2010~"]
Mood = '\uC124\uB818,\uC0AC\uB791' #@param ["ALL","기분전환,신나는","힐링,휴식","설렘,사랑","슬픔,외로움"]

# %%
import random

# 발라드
if (Genre == 'Balad'):
  if (Year == "~1980"):
    if (Mood == '기분전환,신나는'): 
      l=GN0102_tag1  
    elif (Mood == '힐링,휴식'): 
      l=GN0102_tag2  
    elif (Mood == '설렘,사랑'): 
      l=GN0102_tag3  
    elif (Mood == '슬픔,외로움'): 
      l=GN0102_tag4 
    else : 
      l=GN0102_id
  elif (Year == "1990"):
    if (Mood == '기분전환,신나는'):
      l=GN0103_tag1
    elif (Mood == '힐링,휴식'): 
      l=GN0103_tag2
    elif (Mood == '설렘,사랑'):
      l=GN0103_tag3 
    elif (Mood == '슬픔,외로움'):
      l=GN0103_tag4 
    else : 
      l=GN0103_id
  elif (Year == "2000"):
    if (Mood == '기분전환,신나는'):
      l=GN0104_tag1 
    elif (Mood == '힐링,휴식'): 
      l=GN0104_tag2 
    elif (Mood == '설렘,사랑'):
      l=GN0104_tag3  
    elif (Mood == '슬픔,외로움'):
      l=GN0104_tag4 
    else : 
      l=GN0104_id 
  elif (Year == "2010~"):
    if (Mood == '기분전환,신나는'): 
     l=GN0105_tag1
    elif (Mood == '힐링,휴식'): 
      l=GN0105_tag2
    elif (Mood == '설렘,사랑'):
      l=GN0105_tag3 
    elif (Mood == '슬픔,외로움'):
      l=GN0105_tag4
    else : 
      l=GN0105_id
  else :  
    if (Mood == '기분전환,신나는'): 
      l=GN0101_tag1
    elif (Mood == '힐링,휴식'): 
      l=GN0101_tag2
    elif (Mood == '설렘,사랑'):
      l=GN0101_tag3 
    elif (Mood == '슬픔,외로움'):
      l=GN0101_tag4
    else : 
      l=GN0101_id

# 댄스
elif (Genre == 'Dance'):
  if (Year == "~1980"):
    if (Mood == '기분전환,신나는'):
      GN0202_tag1
    elif (Mood == '힐링,휴식'):
      GN0202_tag2 
    elif (Mood == '설렘,사랑'):
      GN0202_tag3 
    elif (Mood == '슬픔,외로움'):
      GN0202_tag4
    else : 
      GN0202_id
  if (Year == "1990"):
    if (Mood == '기분전환,신나는'):
      GN0203_tag1
    elif (Mood == '힐링,휴식'): 
      GN0203_tag2
    elif (Mood == '설렘,사랑'):
      GN0203_tag3
    elif (Mood == '슬픔,외로움'):
      GN0103_tag4
    else : 
      GN0203_id
  elif (Year == "2000"):
    if (Mood == '기분전환,신나는'):
      GN0204_tag1
    elif (Mood == '힐링,휴식'): 
      GN0204_tag2
    elif (Mood == '설렘,사랑'):
      GN0204_tag3 
    elif (Mood == '슬픔,외로움'):
      GN0204_tag4
    else : 
      GN0204_id
  elif (Year == "2010"):
    if (Mood == '기분전환,신나는'):
      GN0205_tag1
    elif (Mood == '힐링,휴식'): 
      GN0205_tag2
    elif (Mood == '설렘,사랑'):
      GN0205_tag3
    elif (Mood == '슬픔,외로움'):
      GN0205_tag4
    else : 
      GN0205_id
  else :
    if (Mood == '기분전환,신나는'): 
      GN0201_tag1
    elif (Mood == '힐링,휴식'): 
      GN0201_tag2
    elif (Mood == '설렘,사랑'):
      GN0201_tag3 
    elif (Mood == '슬픔,외로움'):
      GN0201_tag4
    else : 
      GN0201_id

# 록/메탈
elif (Genre == 'Rock/metal'):
  if (Year == "~1980"):
    if (Mood == '기분전환,신나는'): 
      GN0603_tag1
    elif (Mood == '힐링,휴식'): 
      GN0603_tag2
    elif (Mood == '설렘,사랑'):
      l=GN0603_tag3
    elif (Mood == '슬픔,외로움'):
      GN0603_tag4
    else : 
      GN0603_id
  elif (Year == "1990"):
    if (Mood == '기분전환,신나는'):
      GN0604_tag1 
    elif (Mood == '힐링,휴식'): 
      GN0604_tag2 
    elif (Mood == '설렘,사랑'):
      GN0604_tag3  
    elif (Mood == '슬픔,외로움'):
      GN0604_tag4 
    else : 
      GN0604_id 
  elif (Year == "2000"):
    if (Mood == '기분전환,신나는'):
      GN0605_tag1
    elif (Mood == '힐링,휴식'): 
      GN0605_tag2
    elif (Mood == '설렘,사랑'):
      GN0605_tag3
    elif (Mood == '슬픔,외로움'):
      GN0605_tag4
    else :
      GN0605_id
  elif (Year == "2010~"):
    if (Mood == '기분전환,신나는'):
      GN0606_tag1
    elif (Mood == '힐링,휴식'):
      GN0606_tag2 
    elif (Mood == '설렘,사랑'):
      GN0606_tag3 
    elif (Mood == '슬픔,외로움'):
      GN0606_tag4
    else :
      GN0606_id
  else :
    if (Mood == '기분전환,신나는'): 
      GN0601_tag1
    elif (Mood == '힐링,휴식'):
      GN0601_tag2 
    elif (Mood == '설렘,사랑'):
      GN0601_tag3
    elif (Mood == '슬픔,외로움'):
      GN0601_tag4
    else :
      GN0601_id

# 팝송
elif (Genre == 'POP'):
  if (Year =="(POP)1960-1970"):
    if (Mood == '기분전환,신나는'): 
      GN0905_tag1
    elif (Mood == '힐링,휴식'):
      GN0905_tag2
    elif (Mood == '설렘,사랑'):
      GN0905_tag3 
    elif (Mood == '슬픔,외로움'):
      GN0905_tag4
    else : 
      GN0905_id
  elif (Year == "(POP)1980-1990"):
    if (Mood == '기분전환,신나는'):
      GN0906_tag1 
    elif (Mood == '힐링,휴식'): 
      GN0906_tag2 
    elif (Mood == '설렘,사랑'):
      GN0906_tag3  
    elif (Mood == '슬픔,외로움'):
      GN0906_tag4 
    else : 
      GN0906_id 
  elif (Year == "2000"):
    if (Mood == '기분전환,신나는'): 
      GN0907_tag1 
    elif (Mood == '힐링,휴식'): 
      GN0907_tag2 
    elif (Mood == '설렘,사랑'):
      GN0907_tag3  
    elif (Mood == '슬픔,외로움'):
      GN0907_tag4 
    else : 
      GN0907_id 
  elif (Year == "2010~"):
    if (Mood == '기분전환,신나는'):
      GN0908_tag1  
    elif (Mood == '힐링,휴식'): 
      GN0908_tag2  
    elif (Mood == '설렘,사랑'):
      GN0908_tag3   
    elif (Mood == '슬픔,외로움'):
      GN0908_tag4  
    else : 
      GN0908_id 
  else :
    if (Mood == '기분전환,신나는'):
      GN0901_tag1   
    elif (Mood == '힐링,휴식'): 
      GN0901_tag2 
    elif (Mood == '설렘,사랑'):
      GN0901_tag3  
    elif (Mood == '슬픔,외로움'):
      GN0901_tag4 
    else : 
      GN0901_id

# 랩/힙합
elif (Genre =='Rap/Hipop'):
  if (Mood == "~1980"): 
    if (Mood == '기분전환,신나는'):
      GN1206_tag1     
    elif (Mood == '힐링,휴식'): 
      GN1206_tag2 
    elif (Mood == '설렘,사랑'):
      GN1206_tag3  
    elif (Mood == '슬픔,외로움'):
      GN1206_tag4 
    else : 
      GN1206_id 
  elif (Year == "1990"):
    if (Mood == '기분전환,신나는'): 
      GN1207_tag1 
    elif (Mood == '힐링,휴식'): 
      GN1207_tag2
    elif (Mood == '설렘,사랑'): 
      GN1207_tag3
    elif (Mood == '슬픔,외로움'):
      GN1207_tag4
    else : 
      GN1207_id
  elif (Year == "2000"):
    if (Mood == '기분전환,신나는'):
      GN1208_tag1 
    elif (Mood == '힐링,휴식'): 
      GN1208_tag2 
    elif (Mood == '설렘,사랑'):
      GN1208_tag3  
    elif (Mood == '슬픔,외로움'):
      GN1208_tag4 
    else : 
      GN1208_id
  elif (Year == "2010~"):
    if (Mood == '기분전환,신나는'): 
      GN1209_tag1 
    elif (Mood == '힐링,휴식'): 
      GN1209_tag2 
    elif (Mood == '설렘,사랑'):
      GN1209_tag3  
    elif (Mood == '슬픔,외로움'):
      GN1209_tag4 
    else : 
      GN1209_id 
  else:
    if (Mood == '기분전환,신나는'):
      GN1201_tag1  
    elif (Mood == '힐링,휴식'): 
      GN1201_tag2  
    elif (Mood == '설렘,사랑'): 
      GN1201_tag3  
    elif (Mood == '슬픔,외로움'):
      GN1201_tag4  
    else : 
      GN1201_id

# 모든 장르
else:  
  if (Year =="(POP)1960-1970"):
    if (Mood == '기분전환,신나는'): 
      GN0905_tag1
    elif (Mood == '힐링,휴식'):
      GN0905_tag2
    elif (Mood == '설렘,사랑'):
      GN0905_tag3 
    elif (Mood == '슬픔,외로움'):
      GN0905_tag4
    else : 
      GN0905_id
  elif (Year == "(POP)1980-1990"):
    if (Mood == '기분전환,신나는'):
      GN0906_tag1 
    elif (Mood == '힐링,휴식'): 
      GN0906_tag2 
    elif (Mood == '설렘,사랑'):
      GN0906_tag3  
    elif (Mood == '슬픔,외로움'):
      GN0906_tag4 
    else : 
      GN0906_id 
  elif (Year == "~1980"):
    if (Mood == '기분전환,신나는'): 
      GN0102_tag1+GN0202_tag1+GN0603_tag1+GN1206_tag1
    elif (Mood == '힐링,휴식'): 
      GN0102_tag2+GN0202_tag2+GN0603_tag2+Gn1206_tag2
    elif (Mood == '설렘,사랑'):
      GN0102_tag3+GN0202_tag3+GN0603_tag3+Gn1206_tag3
    elif (Mood == '슬픔,외로움'):
      GN0102_tag4+GN0202_tag4+GN0603_tag4+Gn1206_tag4
    else : 
      GN0102_id+GN0202_id+GN0603_id+Gn1206_id
  elif (Year == "1990"):
    if (Mood == '기분전환,신나는'): 
      GN0103_tag1+GN0203_tag1+GN0604_tag1+GN1207_tag1
    elif (Mood == '힐링,휴식'): 
      GN0103_tag2+GN0203_tag2+GN0604_tag2+GN1207_tag2
    elif (Mood == '설렘,사랑'): 
      GN0103_tag3 +GN0203_tag3+GN0604_tag3+GN1207_tag3
    elif (Mood == '슬픔,외로움'):
      GN0103_tag4+GN0203_tag4+GN0604_tag4+GN1207_tag4
    else :
      GN0103_id+GN0203_id+GN0604_id+GN1207_id
  elif (Year == "2000"):
    if (Mood == '기분전환,신나는'): 
      GN0104_tag1+GN0204_tag1+GN0605_tag1+GN0907_tag1+GN1208_tag1
    elif (Mood == '힐링,휴식'): 
      GN0104_tag2+GN0204_tag2+GN0605_tag2+GN0907_tag2+GN1208_tag2
    elif (Mood == '설렘,사랑'): 
      GN0104_tag3+GN0204_tag3+GN0605_tag3+GN0907_tag3+GN1208_tag3
    elif (Mood == '슬픔,외로움'):
      GN0104_tag4+GN0204_tag4+GN0605_tag4+GN0907_tag4+GN1208_tag4
    else : 
      GN0104_id+GN0204_id+GN0605_id+GN1208_id
  elif (Year == "2010~"):
    if (Mood == '기분전환,신나는'): 
      GN0105_tag1+GN0205_tag1+GN0606_tag1+GN0908_tag1+GN1209_tag1
    elif (Mood == '힐링,휴식'): 
      GN0105_tag2+GN0205_tag2+GN0606_tag2+GN0908_tag2+GN1209_tag2
    elif (Mood == '설렘,사랑'):
      GN0105_tag3+GN0205_tag3+GN0606_tag3+GN0908_tag3+GN1209_tag3
    elif (Mood == '슬픔,외로움'):
      GN0105_tag4+GN0205_tag4+GN0606_tag4+GN0908_tag4+GN1209_tag4
    else : 
      GN0105_id+GN0205_id+GN0606_id+GN0908_id+GN1209_id
  else :
    if (Mood == '기분전환,신나는'): 
      GN0101_tag1+GN0201_tag1+GN0601_tag1+GN0901_tag1+GN1201_tag1
    elif (Mood == '힐링,휴식'): 
      GN0101_tag2+GN0201_tag2+GN0601_tag2+GN0901_tag2+GN1201_tag2
    elif (Mood == '설렘,사랑'): 
      GN0101_tag3+GN0201_tag3+GN0601_tag3+GN0901_tag3+GN1201_tag3
    elif (Mood == '슬픔,외로움'):
      GN0101_tag4+GN0201_tag4+GN0601_tag4+GN0901_tag4+GN1201_tag4
    else : 
      GN0101_id+GN0201_id+GN0601_id+GN0901_id+GN1201_id

song[song_meta['id'].isin(random.sample(l,10))].assign(mood = Mood)
